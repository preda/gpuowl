# %%
import pm1

exponent = 100000000
factored = 77
debug = False
pm1.walk(exponent, factored, debug=debug)
# Out:
# [MIN]: B1=260K, B2=  7M : p=2.38% (0.80% + 1.58%), work=0.96% (0.45% + 0.52%)
# [MID]: B1=600K, B2= 20M : p=3.38% (1.22% + 2.16%), work=2.41% (1.04% + 1.40%)
# [BIG]: B1=  1M, B2= 34M : p=4.01% (1.53% + 2.47%), work=3.99% (1.73% + 2.31%)
